# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
from typing import List

# %%
ovr_db = pd.read_excel(r"C:\Users\n740789\Documents\Projects_local\DataSets\overrides\202502_BBDD_Overrides.xlsx",
                   sheet_name="OVR DB")

# %%
# read latest datafeed at the issuer level
target_columns = [
    "issuer_name",
    "permid",
    "clarityid",
    "company_inheriting",
    "parent_company",
    "str_001_s",
    "str_002_ec",
    "str_003_ec",
    "str_003b_ec",
    "str_004_asec",
    "str_005_ec",
    "cs_001_sec",
    "cs_003_sec",
    "cs_002_ec",
    "str_006_sec",
    "art_8_basicos"
]

datafeed = pd.read_csv(
    r"C:\Users\n740789\Documents\Projects_local\DataSets\DATAFEED\ficheros_tratados\2025\20250201_Equities_feed_IssuerLevel_sinOVR.csv",
    usecols=target_columns,
    dtype={"permid": str, "clarityid": str}
)

# %%
# rename df column names

col_dict = {
    "str_001_s" : "str_001",
    "str_002_ec" : "str_002",
    "str_003_ec" : "str_003",
    "str_003b_ec" : "str_003b",
    "str_004_asec" : "str_004",
    "str_005_ec" : "str_005",
    "cs_001_sec" : "cs_001",
    "cs_003_sec" : "cs_003",
    "cs_002_ec" : "cs_002",
    "str_006_sec" : "str_006",
    "art_8_basicos" : "art_8" 
}

datafeed.rename(columns=col_dict, inplace=True)

# %%
ovr_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 69 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   #                                            750 non-null    int64
#  1   Fecha aplicación OVR                         750 non-null    object
#  2   Fecha última revisión                        750 non-null    object
#  3   Próxima revisión                             748 non-null    object
#  4   ClarityID                                    750 non-null    int64
#  5   permId                                       750 non-null    int64
#  6   Sustainalytics ID                            750 non-null    object
#  7   IssuerID                                     747 non-null    object
#  8   Issuer Name                                  750 non-null    object
#  9   SNT-WORLD
# (Y/-)                              735 non-null    object
#  10  PARENT NAME (Aladdin)                        726 non-null    object
#  11  PARENT IssuerID (Aladdin)                    725 non-null    object
#  12  Parent (P) / Subsidiaria independiente (S*)  750 non-null    object
#  13  PARENT NAME (Clarity)                        750 non-null    object
#  14  Parent ClarityID                             748 non-null    object
#  15  GICS_2                                       750 non-null    object
#  16  ORIGINAL STR001                              746 non-null    object
#  17  OVR STR001
# (SEC)                             99 non-null     object
#  18  FINAL
# STR001                                 747 non-null    object
#  19  ORIGINAL STR002                              746 non-null    object
#  20  OVR STR002
# (EC*)                             85 non-null     object
#  21  FINAL
# STR002                                 747 non-null    object
#  22  ORIGINAL STR003                              746 non-null    object
#  23  OVR STR003
# (EC)                              79 non-null     object
#  24  FINAL
# STR003                                 747 non-null    object
#  25  ORIGINAL STR003B                             746 non-null    object
#  26  OVR STR003B
# (EC*)                            74 non-null     object
#  27  FINAL
# STR003B                                747 non-null    object
#  28  ORIGINAL STR004                              746 non-null    object
#  29  OVR STR004
# (SEC)                             102 non-null    object
#  30  OVR STR004 SOST BONDS
# (SEC)                  11 non-null     object
#  31  FINAL
# STR004                                 748 non-null    object
#  32  ORIGINAL STR005                              746 non-null    object
#  33  OVR STR005
# (EC*)                             50 non-null     object
#  34  FINAL
# STR005                                 748 non-null    object
#  35  ORIGINAL STR006                              746 non-null    object
#  36  OVR STR006
# (SEC)                             98 non-null     object
#  37  FINAL
# STR006                                 747 non-null    object
#  38  ORIGINAL STR007                              746 non-null    object
#  39  OVR STR007
# (SEC)                             99 non-null     object
#  40  FINAL
# STR007                                 747 non-null    object
#  41  ORIGINAL CS001                               746 non-null    object
#  42  OVR CS001
# (SEC*)                             30 non-null     object
#  43  FINAL
# CS001                                  747 non-null    object
#  44  ORIGINAL CS002                               746 non-null    object
#  45  OVR CS002
# (EC*)                              77 non-null     object
#  46  FINAL
# CS002                                  747 non-null    object
#  47  ORIGINAL CS003                               746 non-null    object
#  48  OVR CS003
# (SEC)                              80 non-null     object
#  49  FINAL
# CS003                                  747 non-null    object
#  50  ORIGINAL ARTICULO 8                          746 non-null    object
#  51  OVR ARTICULO 8
# (C)                           46 non-null     object
#  52  FINAL
# ART 8                                  747 non-null    object
#  53  OVR Inversión Sostenible                     0 non-null      float64
#  54  Sustainability Rating Anterior               746 non-null    object
#  55  Sustainability Rating Actual                 746 non-null    object
#  56  Controversia Critica Clarity (True/False)    644 non-null    object
#  57  Nivel Controversia Sustainalytics            750 non-null    object
#  58  Temática Controversia Sustainalytics         498 non-null    object
#  59  Exposiciones                                 552 non-null    object
#  60  SR                                           310 non-null    object
#  61  Exp                                          188 non-null    object
#  62  Ctrv                                         82 non-null     object
#  63  Comit                                        219 non-null    object
#  64  Detalle OVR/Observación adicional            750 non-null    object
#  65  Link a las evidencias                        131 non-null    object
#  66  Estatus actual revisión                      738 non-null    object
#  67  Comentario anterior revision                 582 non-null    object
#  68  Emisor afectados por la caida de Refinitiv   193 non-null    object
# dtypes: float64(1), int64(3), object(65)
# memory usage: 404.4+ KB

# %%
# stadarise spelling of columns
ovr_db.columns = ovr_db.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace('\n','_').str.replace("*","")

# rename columns
ovr_db.rename(columns={
    'fecha_aplicación_ovr':'ovr_date',
    'fecha_última_revisión':'last_check_date',
    'próxima_revisión':'next_check_date',
    'snt-world_y/-':'snt_world',
    'sr':'ovr_grounds_srating',
    'exp':'ovr_grounds_exposure',
    'ctrv':'ovr_grounds_controversy',
    'comit':'ovr_grounds_committee',
    'detalle_ovr/observación_adicional':'comments',
    'temática_controversia_sustainalytics':'sustainalytics_controv_detail',
    'exposiciones':'exposure_detail',
    'estatus_actual_revisión':'latest_comment'
}, inplace=True)


ovr_col_dict = {
    "ovr_str001_sec" : "ovr_str001",
    "ovr_str002_ec" : "ovr_str002",
    "ovr_str003_ec" : "ovr_str003",
    "ovr_str003b_ec" : "ovr_str003b",
    "ovr_str004_sec" : "ovr_str004",
    "ovr_str005_ec" : "ovr_str005",
    "ovr_str006_sec" : "ovr_str006",
    "ovr_articulo_8_c" : "ovr_art_8",
    "ovr_cs001_sec" : "ovr_cs001",
    "ovr_cs002_ec" : "ovr_cs002",
    "ovr_cs003_sec" : "ovr_cs003"
}

# rename targe ovr col name
ovr_db.rename(columns=ovr_col_dict, inplace=True)

# make sure column permid is str
ovr_db['permid'] = ovr_db['permid'].astype(str)
ovr_db['clarityid'] = ovr_db['clarityid'].astype(str)


# parse ovr_date, last_check_date, next_check_date to datetime objects
ovr_db['ovr_date'] = pd.to_datetime(ovr_db['ovr_date'], errors='coerce')
ovr_db['last_check_date'] = pd.to_datetime(ovr_db['last_check_date'], errors='coerce')
ovr_db['next_check_date'] = pd.to_datetime(ovr_db['next_check_date'], errors='coerce')
# Out:
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\2540368951.py:44: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ovr_db['ovr_date'] = pd.to_datetime(ovr_db['ovr_date'], errors='coerce')

# %%
# joint comment columns into a single one
ovr_db['comments'] = (
    ovr_db['comments'].fillna('') + '\n\n' +
    'latest_comment:\n' + ovr_db['latest_comment'].fillna('').astype(str) + '\n\n' +
    'sustainalytics_controv_detail:\n' + ovr_db['sustainalytics_controv_detail'].fillna('').astype(str) + '\n\n' +
    'exposure_detail:\n' + ovr_db['exposure_detail'].fillna('').astype(str)
)

# %%
ovr_ground_cols = ['ovr_grounds_srating', 'ovr_grounds_exposure', 'ovr_grounds_controversy', 'ovr_grounds_committee']
for col in ovr_ground_cols:
    ovr_db[col] = (
        ovr_db[col]
        .astype("string")  # Ensures Pandas' string dtype (not object)
        .str.strip()
        .str.replace(" ", "", regex=False)
        .str.lower()
        .str.replace("c", "x", regex=False)
        .replace(["", "nan", "<NA>", "<na>"], np.nan)  # Unify missing values
    )

# %%
[ovr_db[f'{col}'].value_counts(dropna=False) for col in ovr_ground_cols]
# Out:
# [ovr_grounds_srating
#  <NA>    441
#  x       309
#  Name: count, dtype: Int64,
#  ovr_grounds_exposure
#  <NA>    562
#  x       188
#  Name: count, dtype: Int64,
#  ovr_grounds_controversy
#  <NA>    668
#  x        82
#  Name: count, dtype: Int64,
#  ovr_grounds_committee
#  <NA>    531
#  x       219
#  Name: count, dtype: Int64]

# %% [markdown]
# Remove unecesary columns and generate fileterd dfs

# %%
# let's get rig of str_007
# drop columns with indices 38,39, 40
ovr_db_filtered = ovr_db.drop(ovr_db.columns[[38, 39, 40]], axis=1).copy()

# %%
# List of columns to process
ovr_col_list = [
    "ovr_str001",
    "ovr_str002",
    "ovr_str003",
    "ovr_str003b",
    "ovr_str004",
    "ovr_str005",
    "ovr_str006",
    "ovr_art_8",
    "ovr_cs001",
    "ovr_cs002",
    "ovr_cs003"
]

# %% [markdown]
# Display results

# %%
print(f"There are {len(ovr_db.permid.unique())} unique permids while the df has {len(ovr_db)} rows")

print("display overrides by year month")
print(ovr_db.ovr_date.dt.strftime('%Y_%m').value_counts(dropna=False).sort_index())


print("display overrides by strategy")
[print(ovr_db[col].value_counts(dropna=True, normalize=True).round(2), '\n') for col in ovr_col_list]
# Out:
# There are 746 unique permids while the df has 750 rows
# display overrides by year month
# ovr_date
# 2022_02      2
# 2022_06     13
# 2022_07      1
# 2022_08      1
# 2022_09      2
# 2022_10     12
# 2022_11    162
# 2022_12      3
# 2023_02      4
# 2023_03      3
# 2023_04      3
# 2023_06      7
# 2023_08      2
# 2023_10      2
# 2023_11      9
# 2023_12      3
# 2024_01      4
# 2024_02     25
# 2024_04      2
# 2024_05    139
# 2024_06      2
# 2024_07      2
# 2024_08      5
# 2024_10     44
# 2024_12      1
# 2025_02      3
# NaN        294
# Name: count, dtype: int64
# display overrides by strategy
# ovr_str001
# OK          0.70
# FLAG        0.16
# EXCLUDED    0.14
# Name: proportion, dtype: float64
#
# ovr_str002
# EXCLUDED    0.52
# OK          0.48
# Name: proportion, dtype: float64
#
# ovr_str003
# OK          0.61
# EXCLUDED    0.25
# FLAG        0.14
# Name: proportion, dtype: float64
#
# ovr_str003b
# OK          0.82
# EXCLUDED    0.12
# FLAG        0.05
# Name: proportion, dtype: float64
#
# ovr_str004
# OK          0.77
# FLAG        0.13
# EXCLUDED    0.10
# Name: proportion, dtype: float64
#
# ovr_str005
# OK          0.58
# EXCLUDED    0.40
# FLAG        0.02
# Name: proportion, dtype: float64
#
# ovr_str006
# OK          0.69
# FLAG        0.16
# EXCLUDED    0.14
# Name: proportion, dtype: float64
#
# ovr_art_8
# FLAG        0.37
# EXCLUDED    0.37
# OK          0.26
# Name: proportion, dtype: float64
#
# ovr_cs001
# EXCLUDED    0.40
# FLAG        0.33
# OK          0.27
# Name: proportion, dtype: float64
#
# ovr_cs002
# OK          0.82
# EXCLUDED    0.10
# FLAG        0.08
# Name: proportion, dtype: float64
#
# ovr_cs003
# OK          0.75
# FLAG        0.21
# EXCLUDED    0.04
# Name: proportion, dtype: float64
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
# merge df_filtered with datafeed on permid
ovr_db_datafeed = pd.merge(ovr_db_filtered, datafeed, on='clarityid', how='left')

# %%
print(ovr_db_datafeed.shape[0])
# Out:
# 750

# %%
ovr_db_datafeed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 81 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   #                                           750 non-null    int64
#  1   ovr_date                                    456 non-null    datetime64[ns]
#  2   last_check_date                             564 non-null    datetime64[ns]
#  3   next_check_date                             482 non-null    datetime64[ns]
#  4   clarityid                                   750 non-null    object
#  5   permid_x                                    750 non-null    object
#  6   sustainalytics_id                           750 non-null    object
#  7   issuerid                                    747 non-null    object
#  8   issuer_name_x                               750 non-null    object
#  9   snt_world                                   735 non-null    object
#  10  parent_name_aladdin                         726 non-null    object
#  11  parent_issuerid_aladdin                     725 non-null    object
#  12  parent_p_/_subsidiaria_independiente_s      750 non-null    object
#  13  parent_name_clarity                         750 non-null    object
#  14  parent_clarityid                            748 non-null    object
#  15  gics_2                                      750 non-null    object
#  16  original_str001                             746 non-null    object
#  17  ovr_str001                                  99 non-null     object
#  18  final_str001                                747 non-null    object
#  19  original_str002                             746 non-null    object
#  20  ovr_str002                                  85 non-null     object
#  21  final_str002                                747 non-null    object
#  22  original_str003                             746 non-null    object
#  23  ovr_str003                                  79 non-null     object
#  24  final_str003                                747 non-null    object
#  25  original_str003b                            746 non-null    object
#  26  ovr_str003b                                 74 non-null     object
#  27  final_str003b                               747 non-null    object
#  28  original_str004                             746 non-null    object
#  29  ovr_str004                                  102 non-null    object
#  30  ovr_str004_sost_bonds_sec                   11 non-null     object
#  31  final_str004                                748 non-null    object
#  32  original_str005                             746 non-null    object
#  33  ovr_str005                                  50 non-null     object
#  34  final_str005                                748 non-null    object
#  35  original_str006                             746 non-null    object
#  36  ovr_str006                                  98 non-null     object
#  37  final_str006                                747 non-null    object
#  38  original_cs001                              746 non-null    object
#  39  ovr_cs001                                   30 non-null     object
#  40  final_cs001                                 747 non-null    object
#  41  original_cs002                              746 non-null    object
#  42  ovr_cs002                                   77 non-null     object
#  43  final_cs002                                 747 non-null    object
#  44  original_cs003                              746 non-null    object
#  45  ovr_cs003                                   80 non-null     object
#  46  final_cs003                                 747 non-null    object
#  47  original_articulo_8                         746 non-null    object
#  48  ovr_art_8                                   46 non-null     object
#  49  final_art_8                                 747 non-null    object
#  50  ovr_inversión_sostenible                    0 non-null      float64
#  51  sustainability_rating_anterior              746 non-null    object
#  52  sustainability_rating_actual                746 non-null    object
#  53  controversia_critica_clarity_true/false     644 non-null    object
#  54  nivel_controversia_sustainalytics           750 non-null    object
#  55  sustainalytics_controv_detail               498 non-null    object
#  56  exposure_detail                             552 non-null    object
#  57  ovr_grounds_srating                         309 non-null    string
#  58  ovr_grounds_exposure                        188 non-null    string
#  59  ovr_grounds_controversy                     82 non-null     string
#  60  ovr_grounds_committee                       219 non-null    string
#  61  comments                                    750 non-null    object
#  62  link_a_las_evidencias                       131 non-null    object
#  63  latest_comment                              738 non-null    object
#  64  comentario_anterior_revision                582 non-null    object
#  65  emisor_afectados_por_la_caida_de_refinitiv  193 non-null    object
#  66  issuer_name_y                               746 non-null    object
#  67  company_inheriting                          746 non-null    object
#  68  parent_company                              746 non-null    object
#  69  str_001                                     746 non-null    object
#  70  str_002                                     746 non-null    object
#  71  str_003                                     746 non-null    object
#  72  str_004                                     746 non-null    object
#  73  str_005                                     746 non-null    object
#  74  cs_001                                      746 non-null    object
#  75  cs_003                                      746 non-null    object
#  76  cs_002                                      746 non-null    object
#  77  str_006                                     746 non-null    object
#  78  art_8                                       746 non-null    object
#  79  permid_y                                    746 non-null    object
#  80  str_003b                                    746 non-null    object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(72), string(4)
# memory usage: 474.7+ KB

# %%
def drop_columns_by_prefix(df, prefixes):
    columns_to_drop = [col for col in df.columns if any(col.startswith(prefix) for prefix in prefixes)]
    return df.drop(columns=columns_to_drop)

# Drop columns starting with "original_" or "final_"
prefixes_to_remove = ["original_", "final_"]
ovr_db_datafeed = drop_columns_by_prefix(ovr_db_datafeed, prefixes_to_remove)

# %%
#rename column permid_x and issuer_name_x df_datafeed to permid and issuer_name
ovr_db_datafeed.rename(columns={
    'permid_x':'permid',
    'issuer_name_x':'issuer_name'
}, inplace=True)

result_target_columns = [
    "last_check_date",
    "next_check_date",
    'permid',
    "clarityid",
    'issuer_name',
    "company_inheriting",
    "parent_company",
    "ovr_str001",
    "ovr_str002",
    "ovr_str003",
    "ovr_str003b",
    "ovr_str004",
    "ovr_str005",
    "ovr_str006",
    "ovr_cs001",
    "ovr_cs002",
    "ovr_cs003",
    "ovr_art_8",
    "str_001",
    "str_002",
    "str_003",
    "str_003b",
    "str_004",
    "str_005",
    "str_006",
    "art_8",
    "cs_001",
    "cs_003",
    "cs_002",
    "ovr_grounds_srating",
    "ovr_grounds_exposure",
    "ovr_grounds_controversy",
    "ovr_grounds_committee",
    "comments",
]


# filter df_datafeed to only include the columns in result_target_columns
result_df = ovr_db_datafeed[result_target_columns].copy()

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   last_check_date          564 non-null    datetime64[ns]
#  1   next_check_date          482 non-null    datetime64[ns]
#  2   permid                   750 non-null    object
#  3   clarityid                750 non-null    object
#  4   issuer_name              750 non-null    object
#  5   company_inheriting       746 non-null    object
#  6   parent_company           746 non-null    object
#  7   ovr_str001               99 non-null     object
#  8   ovr_str002               85 non-null     object
#  9   ovr_str003               79 non-null     object
#  10  ovr_str003b              74 non-null     object
#  11  ovr_str004               102 non-null    object
#  12  ovr_str005               50 non-null     object
#  13  ovr_str006               98 non-null     object
#  14  ovr_cs001                30 non-null     object
#  15  ovr_cs002                77 non-null     object
#  16  ovr_cs003                80 non-null     object
#  17  ovr_art_8                46 non-null     object
#  18  str_001                  746 non-null    object
#  19  str_002                  746 non-null    object
#  20  str_003                  746 non-null    object
#  21  str_003b                 746 non-null    object
#  22  str_004                  746 non-null    object
#  23  str_005                  746 non-null    object
#  24  str_006                  746 non-null    object
#  25  art_8                    746 non-null    object
#  26  cs_001                   746 non-null    object
#  27  cs_003                   746 non-null    object
#  28  cs_002                   746 non-null    object
#  29  ovr_grounds_srating      309 non-null    string
#  30  ovr_grounds_exposure     188 non-null    string
#  31  ovr_grounds_controversy  82 non-null     string
#  32  ovr_grounds_committee    219 non-null    string
#  33  comments                 750 non-null    object
# dtypes: datetime64[ns](2), object(28), string(4)
# memory usage: 199.3+ KB

# %%
def active_ovr(row, column_pairs):
    result = {}
    for ovr_col, base_col in column_pairs:
        if pd.isna(row[ovr_col]) or pd.isna(row[base_col]):
            result[f"{ovr_col}_active"] = np.nan
        else:
            result[f"{ovr_col}_active"] = row[ovr_col] != row[base_col]
    return result

# %%
# Define column pairs to compare based on the provided columns
column_pairs_to_compare = [
    ("ovr_str001", "str_001"),
    ("ovr_str002", "str_002"),
    ("ovr_str003", "str_003"),
    ("ovr_str003b", "str_003b"),
    ("ovr_str004", "str_004"),
    ("ovr_str005", "str_005"),
    ("ovr_str006", "str_006"),
    ("ovr_cs001", "cs_001"),
    ("ovr_cs002", "cs_002"),
    ("ovr_cs003", "cs_003"),
    ("ovr_art_8", "art_8"),
]

# Add new columns for each override
for index, row in result_df.iterrows():
    active_overrides = active_ovr(row, column_pairs_to_compare)
    for col, value in active_overrides.items():
        result_df.at[index, col] = value
# Out:
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value
# C:\Users\n740789\AppData\Local\Temp\ipykernel_14700\3656545810.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[index, col] = value

# %%
# Define column pairs to compare based on the provided columns
column_pairs_to_compare = [
    ("ovr_str001", "str_001"),
    ("ovr_str002", "str_002"),
    ("ovr_str003", "str_003"),
    ("ovr_str003b", "str_003b"),
    ("ovr_str004", "str_004"),
    ("ovr_str005", "str_005"),
    ("ovr_str006", "str_006"),
    ("ovr_cs001", "cs_001"),
    ("ovr_cs002", "cs_002"),
    ("ovr_cs003", "cs_003"),
    ("ovr_art_8", "art_8"),
]

# %%
def save_result_df_to_excel(result_df, output_file, basic_columns):

    aux_col = [
    "ovr_grounds_srating",
    "ovr_grounds_exposure",
    "ovr_grounds_controversy",
    "ovr_grounds_committee",
    "comments",
    "company_inheriting",
    "parent_company",
    ]


    output_dir = os.path.dirname(output_file)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    strategy_columns = [
        "str_001", "str_002", "str_003", "str_003b", 
        "str_004", "str_005","str_006", "art_8",
        "cs_001", "cs_002", "cs_003" 
    ]

    ovr_columns = [
        "ovr_str001", "ovr_str002", "ovr_str003", "ovr_str003b", 
        "ovr_str004", "ovr_str005", "ovr_str006", "ovr_art_8",
        "ovr_cs001", "ovr_cs002", "ovr_cs003"
    ]

    ovr_active_columns = [
        "ovr_str001_active", "ovr_str002_active", "ovr_str003_active", "ovr_str003b_active",
        "ovr_str004_active", "ovr_str005_active", "ovr_str006_active", "ovr_art_8_active",
        "ovr_cs001_active", "ovr_cs002_active", "ovr_cs003_active", 
    ]

    with pd.ExcelWriter(output_file, engine="xlsxwriter") as writer:
        result_df.to_excel(writer, sheet_name="Full_Data", index=False)

        for strategy, ovr_col, active_col in zip(strategy_columns, ovr_columns, ovr_active_columns):
            result_df["ovr_target"] = strategy
            relevant_columns = basic_columns + ["ovr_target"] + [
                col for col in [strategy, ovr_col, active_col] if col in result_df.columns
            ] + aux_col

            if relevant_columns:
                result_df[relevant_columns].to_excel(writer, sheet_name=f"{strategy}", index=False)

    print(f"Data has been successfully saved to {output_file}")

# %%
def ovr_to_dfs(result_df, output_file, basic_columns) -> List[pd.DataFrame]:

    aux_col = [
    "ovr_grounds_srating",
    "ovr_grounds_exposure",
    "ovr_grounds_controversy",
    "ovr_grounds_committee",
    "comments",
    "company_inheriting",
    "parent_company",
    ]


    output_dir = os.path.dirname(output_file)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    strategy_columns = [
        "str_001", "str_002", "str_003", "str_003b", 
        "str_004", "str_005","str_006", "art_8",
        "cs_001", "cs_002", "cs_003" 
    ]

    ovr_columns = [
        "ovr_str001", "ovr_str002", "ovr_str003", "ovr_str003b", 
        "ovr_str004", "ovr_str005", "ovr_str006", "ovr_art_8",
        "ovr_cs001", "ovr_cs002", "ovr_cs003"
    ]

    ovr_active_columns = [
        "ovr_str001_active", "ovr_str002_active", "ovr_str003_active", "ovr_str003b_active",
        "ovr_str004_active", "ovr_str005_active", "ovr_str006_active", "ovr_art_8_active",
        "ovr_cs001_active", "ovr_cs002_active", "ovr_cs003_active", 
    ]

    with pd.ExcelWriter(output_file, engine="xlsxwriter") as writer:
        result_df.to_excel(writer, sheet_name="Full_Data", index=False)

        for strategy, ovr_col, active_col in zip(strategy_columns, ovr_columns, ovr_active_columns):
            result_df["ovr_target"] = strategy
            relevant_columns = basic_columns + ["ovr_target"] + [
                col for col in [strategy, ovr_col, active_col] if col in result_df.columns
            ] + aux_col

            if relevant_columns:
                result_df[relevant_columns].to_excel(writer, sheet_name=f"{strategy}", index=False)

    print(f"Data has been successfully saved to {output_file}")

# %%
DATE = datetime.now().strftime("%Y%m%d")

# define basic columns before saving
basic_columns = [
    "last_check_date",
    "next_check_date",
    "permid",
    "issuer_name",
]
save_result_df_to_excel(result_df, rf"output\{DATE}_override_analysis_issuer.xlsx", basic_columns=basic_columns)
# Out:
# Data has been successfully saved to output\20250217_override_analysis.xlsx

# %%
result_df.head()

# %%
columns_to_check = [
    'ovr_grounds_srating',
    'ovr_grounds_exposure',
    'ovr_grounds_controversy',
    'ovr_grounds_committee'
]

filter_test = result_df[result_df[columns_to_check].notna().sum(axis=1)>1]

# %%
filter_test[["issuer_name"]+columns_to_check].head(10)

# %%
for col in result_df.columns:
    if col.endswith("_active"):
        print(result_df[col].value_counts(dropna=True))
        print("\n")

# %% [markdown]
# # Explore Mexico Issuers
#
#
# Número de Emisores en Mexico: 269
# Data relevance
#     -avg
#     -segmentar /grouping
#
# ESG Scoring & Sust Rating
#     -avg
#     -segment /groupin
#     -Top & Bottom Outlayers

# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\n740789\Documents\Projects_local\DataSets\DATAFEED\ficheros_tratados\2025\20250201_Equities_feed_IssuerLevel_sinOVR.csv"

df = pd.read_csv(path)

# %%
# remove limit output cell
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
df.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69264 entries, 0 to 69263
# Data columns (total 276 columns):
#  #    Column                                              Dtype
# ---   ------                                              -----
#  0    isin                                                object
#  1    instrument_type                                     object
#  2    issuer_name                                         object
#  3    issuer_country                                      object
#  4    gics2_industry                                      object
#  5    region                                              object
#  6    company_inheriting                                  bool
#  7    parent_company                                      object
#  8    esg_score                                           int64
#  9    esg_score_relevance                                 float64
#  10   e_score                                             float64
#  11   s_score                                             int64
#  12   g_score                                             int64
#  13   esg_rating                                          object
#  14   sustainability_rating                               object
#  15   global_sustainability_rating                        object
#  16   controv_access_to_basic_services                    float64
#  17   critical_controv_access_to_basic_services           bool
#  18   controv_accounting_and_taxation                     float64
#  19   critical_controv_accounting_and_taxation            bool
#  20   controv_animal_welfare                              float64
#  21   critical_controv_animal_welfare                     bool
#  22   controv_animal_welfare_sc                           float64
#  23   critical_controv_animal_welfare_sc                  bool
#  24   controv_anticompetitive_practices                   float64
#  25   critical_controv_anticompetitive_practices          bool
#  26   controv_bribery_and_corruption                      float64
#  27   critical_controv_bribery_and_corruption             bool
#  28   controv_bribery_and_corruption_sc                   float64
#  29   critical_controv_bribery_and_corruption_sc          bool
#  30   controv_business_ethics                             float64
#  31   critical_controv_business_ethics                    bool
#  32   controv_business_ethics_sc                          float64
#  33   critical_controv_business_ethics_sc                 bool
#  34   controv_carbon_impact_of_products                   float64
#  35   critical_controv_carbon_impact_of_products          bool
#  36   controv_community_relations                         float64
#  37   critical_controv_community_relations                bool
#  38   controv_community_relations_sc                      float64
#  39   critical_controv_community_relations_sc             bool
#  40   controv_corporate_governance                        float64
#  41   critical_controv_corporate_governance               bool
#  42   controv_data_privacy_and_security                   float64
#  43   critical_controv_data_privacy_and_security          bool
#  44   controv_emissions_effluents_and_waste               float64
#  45   critical_controv_emissions_effluents_and_waste      bool
#  46   controv_emissions_effluents_and_waste_sc            float64
#  47   critical_controv_emissions_effluents_and_waste_sc   bool
#  48   controv_employees_human_rights                      float64
#  49   critical_controv_employees_human_rights             bool
#  50   controv_employees_human_rights_sc                   float64
#  51   critical_controv_employees_human_rights_sc          bool
#  52   controv_energy_use_and_ghg_emissions                float64
#  53   critical_controv_energy_use_and_ghg_emissions       bool
#  54   controv_energy_use_and_ghg_emissions_sc             float64
#  55   critical_controv_energy_use_and_ghg_emissions_sc    bool
#  56   controv_environmental_impact_of_products            float64
#  57   critical_controv_environmental_impact_of_products   bool
#  58   controv_intellectual_property                       float64
#  59   critical_controv_intellectual_property              bool
#  60   controv_labour_relations                            float64
#  61   critical_controv_labour_relations                   bool
#  62   controv_labour_relations_sc                         float64
#  63   critical_controv_labour_relations_sc                bool
#  64   controv_land_use_and_biodiversity                   float64
#  65   critical_controv_land_use_and_biodiversity          bool
#  66   controv_land_use_and_biodiversity_sc                float64
#  67   critical_controv_land_use_and_biodiversity_sc       bool
#  68   controv_lobbying_and_public_policy                  float64
#  69   critical_controv_lobbying_and_public_policy         bool
#  70   controv_marketing_practices                         float64
#  71   critical_controv_marketing_practices                bool
#  72   controv_media_ethics                                float64
#  73   critical_controv_media_ethics                       bool
#  74   controv_occupational_health_and_safety              float64
#  75   critical_controv_occupational_health_and_safety     bool
#  76   controv_occupational_health_and_safety_sc           float64
#  77   critical_controv_occupational_health_and_safety_sc  bool
#  78   controv_quality_and_safety                          float64
#  79   critical_controv_quality_and_safety                 bool
#  80   controv_sanctions                                   float64
#  81   critical_controv_sanctions                          bool
#  82   controv_social_impact_of_products                   float64
#  83   critical_controv_social_impact_of_products          bool
#  84   controv_society_human_rights                        float64
#  85   critical_controv_society_human_rights               bool
#  86   controv_society_human_rights_sc                     float64
#  87   critical_controv_society_human_rights_sc            bool
#  88   controv_water_use                                   float64
#  89   critical_controv_water_use                          bool
#  90   controv_water_use_sc                                float64
#  91   critical_controv_water_use_sc                       bool
#  92   controv_weapons                                     float64
#  93   critical_controv_weapons                            bool
#  94   any_critical_controversy                            bool
#  95   exp_abortifacents_part                              bool
#  96   minexp_abortifacents_part                           float64
#  97   maxexp_abortifacents_part                           float64
#  98   exp_agrochemical_products_part                      bool
#  99   minexp_agrochemical_products_part                   float64
#  100  maxexp_agrochemical_products_part                   float64
#  101  exp_agrochemical_products_prod                      bool
#  102  minexp_agrochemical_products_prod                   float64
#  103  maxexp_agrochemical_products_prod                   float64
#  104  exp_alcohol_part                                    bool
#  105  minexp_alcohol_part                                 float64
#  106  maxexp_alcohol_part                                 float64
#  107  exp_alchol_prod                                     bool
#  108  minexp_alchol_prod                                  float64
#  109  maxexp_alchol_prod                                  float64
#  110  exp_animal_testing_part                             bool
#  111  minexp_animal_testing_part                          float64
#  112  maxexp_animal_testing_part                          float64
#  113  exp_animal_testing_cosmetic_part                    bool
#  114  minexp_animal_testing_cosmetic_part                 float64
#  115  maxexp_animal_testing_cosmetic_part                 float64
#  116  exp_antip_landmines_part                            bool
#  117  minexp_antip_landmines_part                         float64
#  118  maxexp_antip_landmines_part                         float64
#  119  exp_armament_part                                   bool
#  120  minexp_armament_part                                float64
#  121  maxexp_armament_part                                float64
#  122  exp_armament_prod                                   bool
#  123  minexp_armament_prod                                float64
#  124  maxexp_armament_prod                                float64
#  125  exp_chemic_biolog_weapons_part                      bool
#  126  minexp_chemic_biolog_weapons_part                   float64
#  127  maxexp_chemic_biolog_weapons_part                   float64
#  128  exp_cluster_bombs_part                              bool
#  129  minexp_cluster_bombs_part                           float64
#  130  maxexp_cluster_bombs_part                           float64
#  131  exp_coal_mining_part                                bool
#  132  minexp_coal_mining_part                             float64
#  133  maxexp_coal_mining_part                             float64
#  134  exp_coal_mining_prod                                bool
#  135  minexp_coal_mining_prod                             float64
#  136  maxexp_coal_mining_prod                             float64
#  137  exp_coal_power_gen_part                             bool
#  138  minexp_coal_power_gen_part                          float64
#  139  maxexp_coal_power_gen_part                          float64
#  140  exp_coal_power_gen_prod                             bool
#  141  minexp_coal_power_gen_prod                          float64
#  142  maxexp_coal_power_gen_prod                          float64
#  143  exp_contraceptives_part                             bool
#  144  minexp_contraceptives_part                          float64
#  145  maxexp_contraceptives_part                          float64
#  146  exp_depleted_uranium_part                           bool
#  147  minexp_depleted_uranium_part                        float64
#  148  maxexp_depleted_uranium_part                        float64
#  149  exp_embryonic_stem_cell_research_part               bool
#  150  minexp_embryonic_stem_cell_research_part            float64
#  151  maxexp_embryonic_stem_cell_research_part            float64
#  152  exp_fossil_fuels_part                               bool
#  153  minexp_fossil_fuels_part                            float64
#  154  maxexp_fossil_fuels_part                            float64
#  155  exp_fossil_fuels_prod                               bool
#  156  minexp_fossil_fuels_prod                            float64
#  157  maxexp_fossil_fuels_prod                            float64
#  158  exp_fur_exotic_leather_part                         bool
#  159  minexp_fur_exotic_leather_part                      float64
#  160  maxexp_fur_exotic_leather_part                      float64
#  161  exp_gambling_part                                   bool
#  162  minexp_gambling_part                                float64
#  163  maxexp_gambling_part                                float64
#  164  exp_gambling_prod                                   bool
#  165  minexp_gambling_prod                                float64
#  166  maxexp_gambling_prod                                float64
#  167  exp_gmo_products_part                               bool
#  168  minexp_gmo_products_part                            float64
#  169  maxexp_gmo_products_part                            float64
#  170  exp_gmo_research_part                               bool
#  171  minexp_gmo_research_part                            float64
#  172  maxexp_gmo_research_part                            float64
#  173  exp_meat_products_part                              bool
#  174  minexp_meat_products_part                           float64
#  175  maxexp_meat_products_part                           float64
#  176  exp_meat_products_prod                              bool
#  177  minexp_meat_products_prod                           float64
#  178  maxexp_meat_products_prod                           float64
#  179  exp_cannabis_part                                   bool
#  180  minexp_cannabis_part                                float64
#  181  maxexp_cannabis_part                                float64
#  182  exp_nuclear_energy_part                             bool
#  183  minexp_nuclear_energy_part                          float64
#  184  maxexp_nuclear_energy_part                          float64
#  185  exp_nuclear_energy_prod                             bool
#  186  minexp_nuclear_energy_prod                          float64
#  187  maxexp_nuclear_energy_prod                          float64
#  188  exp_nuclear_weapons_part                            bool
#  189  minexp_nuclear_weapons_part                         float64
#  190  maxexp_nuclear_weapons_part                         float64
#  191  exp_oil_sands_part                                  bool
#  192  minexp_oil_sands_part                               float64
#  193  maxexp_oil_sands_part                               float64
#  194  exp_oil_sands_prod                                  bool
#  195  minexp_oil_sands_prod                               float64
#  196  maxexp_oil_sands_prod                               float64
#  197  exp_palm_oil_part                                   bool
#  198  minexp_palm_oil_part                                float64
#  199  maxexp_palm_oil_part                                float64
#  200  exp_pork_products_part                              bool
#  201  minexp_pork_products_part                           float64
#  202  maxexp_pork_products_part                           float64
#  203  exp_pork_products_prod                              bool
#  204  minexp_pork_products_prod                           float64
#  205  maxexp_pork_products_prod                           float64
#  206  exp_pornography_part                                bool
#  207  minexp_pornography_part                             float64
#  208  maxexp_pornography_part                             float64
#  209  exp_shale_energy_part                               bool
#  210  minexp_shale_energy_part                            float64
#  211  maxexp_shale_energy_part                            float64
#  212  exp_shale_energy_prod                               bool
#  213  minexp_shale_energy_prod                            float64
#  214  maxexp_shale_energy_prod                            float64
#  215  exp_stem_cell_research                              bool
#  216  minexp_stem_cell_research                           float64
#  217  maxexp_stem_cell_research                           float64
#  218  exp_tobacco_part                                    bool
#  219  minexp_tobacco_part                                 float64
#  220  maxexp_tobacco_part                                 float64
#  221  exp_tobacco_prod                                    bool
#  222  minexp_tobacco_prod                                 float64
#  223  maxexp_tobacco_prod                                 float64
#  224  exp_artic_oil_part                                  bool
#  225  minexp_artic_oil_part                               float64
#  226  maxexp_artic_oil_part                               float64
#  227  exp_predatory_lending_part                          bool
#  228  minexp_predatory_lending_part                       float64
#  229  maxexp_predatory_lending_part                       float64
#  230  exp_small_arms_part                                 bool
#  231  minexp_small_arms_part                              float64
#  232  maxexp_small_arms_part                              float64
#  233  exp_white_phosporus_part                            bool
#  234  minexp_white_phosporus_part                         float64
#  235  maxexp_white_phosporus_part                         float64
#  236  str_001_s                                           object
#  237  str_002_ec                                          object
#  238  str_003_ec                                          object
#  239  str_004_asec                                        object
#  240  clarityid                                           int64
#  241  str_005_ec                                          object
#  242  cs_001_sec                                          object
#  243  gp_esccp                                            object
#  244  cs_003_sec                                          object
#  245  cs_002_ec                                           object
#  246  str_006_sec                                         object
#  247  str_007_sect                                        object
#  248  gp_esccp_22                                         object
#  249  gp_esccp_25                                         object
#  250  gp_esccp_30                                         object
#  251  art_8_basicos                                       object
#  252  permid                                              int64
#  253  countrycode                                         object
#  254  str_003b_ec                                         object
#  255  exp_nuclear_weapons_prod                            bool
#  256  minexp_nuclear_weapons_prod                         float64
#  257  maxexp_nuclear_weapons_prod                         float64
#  258  exp_cluster_bombs_prod                              bool
#  259  minexp_cluster_bombs_prod                           float64
#  260  maxexp_cluster_bombs_prod                           float64
#  261  exp_thermal_coal_prod                               bool
#  262  minexp_thermal_coal_prod                            float64
#  263  maxexp_thermal_coal_prod                            float64
#  264  exp_gas_fuels_prod                                  bool
#  265  minexp_gas_fuels_prod                               float64
#  266  maxexp_gas_fuels_prod                               float64
#  267  exp_gas_fuels_part                                  bool
#  268  minexp_gas_fuels_part                               float64
#  269  maxexp_gas_fuels_part                               float64
#  270  exp_oil_fuels_prod                                  bool
#  271  minexp_oil_fuels_prod                               float64
#  272  maxexp_oil_fuels_prod                               float64
#  273  exp_oil_fuels_part                                  bool
#  274  minexp_oil_fuels_part                               float64
#  275  maxexp_oil_fuels_part                               float64
# dtypes: bool(95), float64(149), int64(5), object(27)
# memory usage: 101.9+ MB

# %%
df = df[df.issuer_country=='Mexico'].copy()

# %%
df.shape[0]
# Out:
# 269

# %%
target_cols = ["esg_score", "esg_score_relevance", "esg_rating", "sustainability_rating"]

# Initialize a dictionary to store results
summary_data = {}

for col in target_cols:
    if df[col].dtype in ['int64', 'float64']:  # Numeric Columns
        summary_data[col] = df[col].describe().round(2)
    else:  # Categorical Columns
        summary_data[col] = {
            "Unique Count": df[col].nunique(),
            "Most Common Value": df[col].mode()[0],  # Mode
            "Top 3 Categories": df[col].value_counts().head(3).to_dict(),  # Top 3
            "Most Common Freq": df[col].value_counts().iloc[0]  # Frequency of most common
        }

# Convert to DataFrame for better visualization
summary_df = pd.DataFrame(summary_data)

# %%
summary_df
# Out:
#                    esg_score  esg_score_relevance  \
# 25%                    33.00                63.96
# 50%                    54.00                84.11
# 75%                    67.00                94.29
# Most Common Freq         NaN                  NaN
# Most Common Value        NaN                  NaN
# Top 3 Categories         NaN                  NaN
# Unique Count             NaN                  NaN
# count                 269.00               269.00
# max                    84.00               100.00
# mean                   50.66                74.30
# min                    11.00                22.48
# std                    19.91                24.54
#
#                                      esg_rating  \
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# Most Common Freq                             61
# Most Common Value                             A
# Top 3 Categories   {'A': 61, 'A-': 53, 'C': 45}
# Unique Count                                  7
# count                                       NaN
# max                                         NaN
# mean                                        NaN
# min                                         NaN
# std                                         NaN
#
#                                            sustainability_rating
# 25%                                                          NaN
# 50%                                                          NaN
# 75%                                                          NaN
# Most Common Freq                                              66
# Most Common Value                                           Good
# Top 3 Categories   {'Good': 66, 'Sufficient': 55, 'Average': 47}
# Unique Count                                                   7
# count                                                        NaN
# max                                                          NaN
# mean                                                         NaN
# min                                                          NaN
# std                                                          NaN

# %%
# Define target columns
target_numeric_cols = ["esg_score", "esg_score_relevance"]
target_categorical_cols = ["esg_rating", "sustainability_rating"]

# Define categorical order mapping
esg_rating_order = {'A+': 7, 'A': 6, 'A-': 5, 'B': 4, 'C+': 3, 'C': 2, 'C-': 1}
sustainability_rating_order = {'Outstanding': 7, 'Leader': 6, 'Good': 5, 'Sufficient': 4, 'Average': 3, 'Limited': 2, 'Poor': 1}

# -------------------- NUMERIC SUMMARY --------------------
numeric_summary = {}

for col in target_numeric_cols:
    desc = df[col].describe().round(2)
    
    if not df[col].dropna().empty:  # Ensure non-empty column
        mode_val = df[col].mode()[0]  # Most common value
        mode_freq = df[col].value_counts().iloc[0]  # Frequency of most common value
    else:
        mode_val, mode_freq = None, None  # Handle empty cases
    
    # Use pd.concat() instead of append()
    numeric_summary[col] = pd.concat([desc, pd.Series({
        "Most Common Value": mode_val,
        "Most Common Freq": mode_freq
    })])

numeric_summary_df = pd.DataFrame(numeric_summary)

# -------------------- CATEGORICAL SUMMARY --------------------
categorical_summary = {}

for col in target_categorical_cols:
    valid_data = df[col].dropna()  # Remove NaNs for calculations
    
    if not valid_data.empty:  # Ensure there's data to process
        categorical_summary[col] = {
            "Unique Count": valid_data.nunique(),
            "Most Common Value": valid_data.mode()[0],  # Mode
            "Most Common Freq": valid_data.value_counts().iloc[0],  # Frequency of most common
            "Top 3 Categories": valid_data.value_counts().head(3).to_dict()  # Top 3
        }
    else:
        categorical_summary[col] = {
            "Unique Count": 0,
            "Most Common Value": None,
            "Most Common Freq": None,
            "Top 3 Categories": {}
        }

categorical_summary_df = pd.DataFrame(categorical_summary)

# -------------------- CATEGORICAL PERCENTILES --------------------
categorical_data = df[target_categorical_cols].copy()

# Convert categorical values to numbers based on ranking (handling NaNs)
categorical_data["esg_rating"] = categorical_data["esg_rating"].map(esg_rating_order).dropna()
categorical_data["sustainability_rating"] = categorical_data["sustainability_rating"].map(sustainability_rating_order).dropna()

# Compute percentiles if data is not empty
if not categorical_data.empty:
    categorical_percentiles = categorical_data.quantile([0.25, 0.50, 0.75]).round(2)
    
    # Map back to original categorical labels for interpretation
    categorical_percentiles["esg_rating"] = categorical_percentiles["esg_rating"].map({v: k for k, v in esg_rating_order.items()})
    categorical_percentiles["sustainability_rating"] = categorical_percentiles["sustainability_rating"].map({v: k for k, v in sustainability_rating_order.items()})
else:
    categorical_percentiles = pd.DataFrame(columns=target_categorical_cols)

# -------------------- MERGE CATEGORICAL SUMMARY + PERCENTILES --------------------
merged_categorical_df = pd.concat([categorical_summary_df, categorical_percentiles])

# %%
merged_categorical_df
# Out:
#                                      esg_rating  \
# Unique Count                                  7
# Most Common Value                             A
# Most Common Freq                             61
# Top 3 Categories   {'A': 61, 'A-': 53, 'C': 45}
# 0.25                                          C
# 0.5                                           B
# 0.75                                          A
#
#                                            sustainability_rating
# Unique Count                                                   7
# Most Common Value                                           Good
# Most Common Freq                                              66
# Top 3 Categories   {'Good': 66, 'Sufficient': 55, 'Average': 47}
# 0.25                                                     Average
# 0.5                                                   Sufficient
# 0.75                                                        Good

# %%
numeric_summary_df
# Out:
#                    esg_score  esg_score_relevance
# count                 269.00               269.00
# mean                   50.66                74.30
# std                    19.91                24.54
# min                    11.00                22.48
# 25%                    33.00                63.96
# 50%                    54.00                84.11
# 75%                    67.00                94.29
# max                    84.00               100.00
# Most Common Value      69.00                94.68
# Most Common Freq       16.00                 7.00

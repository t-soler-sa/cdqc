# %%
import pandas as pd
from datetime import datetime
from pathlib import Path
from dateutil.relativedelta import relativedelta
import os

# %%
missing_permids =[
    "5080149298",
    "5064650117",
    "5046041361",
    "5034819615",
    "5000645180",
    "4296092115",
    "4295890178",
    "4295889397",
    "4295866913",
    "4295859326",
    "15765"
]

target_columns = [
    "issuer_name",
    "permid",
    "clarityid",
    "company_inheriting",
    "parent_company",
    "str_001_s",
    "str_002_ec",
    "str_003_ec",
    "str_003b_ec",
    "str_004_asec",
    "str_005_ec",
    "cs_001_sec",
    "cs_003_sec",
    "cs_002_ec",
    "str_006_sec",
    "art_8_basicos"
]

# %%
#get crossreference
crossreference = pd.read_csv(r"C:\Users\n740789\Documents\Projects_local\DataSets\crossreference\Aladdin_Clarity_Issuers_20250301.csv", 
                             dtype={"CLARITY_AI": str})
crossreference.columns = ["brs_id", "brs_issuer_name", "permid", "msci_id", "sustainalytics_id"]
# drop from crossreference columns msci_id and susctainalytics_id
crossreference.drop(columns=["msci_id", "sustainalytics_id"], inplace=True)

# %%
cross_filtered = crossreference[crossreference["permid"].isin(missing_permids)]

# %%
cross_filtered
# Out:
#         brs_id                           brs_issuer_name      permid
# 3989    H82067                   ANHEUSER BUSCH INBEV SA  4295859326
# 35762   F31276                             BP OIL ESPANA  4295889397
# 74308   H14063                           RELX FINANCE BV  5046041361
# 79454   R32112                                BOLIDEN AB  4295890178
# 90954   R66206       COMPAGNIE DE FINANCEMENT FONCIER SA  4296092115
# 116100  J63531      COMPASS GROUP FINANCE NETHERLANDS BV  5064650117
# 124475  J44454       EDP SERVICIOS FINANCIEROS ESPANA SA  5034819615
# 126526  J88119  ACCIONA ENERGIA FINANCIACION FILIALES SA  5080149298

# %%
# Get Date
DATE = datetime.now().strftime("%Y%m")
YEAR = DATE[:4]
date_obj = datetime.strptime(DATE, "%Y%m")
prev_date_obj = date_obj - relativedelta(months=1)
DATE_PREV = prev_date_obj.strftime("%Y%m")

# %%
DATAFEED_DIR = Path(r"C:\Users\n740789\Documents\Projects_local\DataSets\DATAFEED")
DF_FILE_PATH = (
    DATAFEED_DIR
    / "datafeeds_with_ovr"
    / f"{DATE_PREV}_df_issuer_level_with_ovr.csv"
)

# %%
df = pd.read_csv(
    DF_FILE_PATH,
    usecols=target_columns,
    dtype={"permid": str, "clarityid":str},
    )

# %%
df_filtered = df[df["clarityid"].isin(missing_permids)]

# %%
# add brs_id to df_filtered
df_filtered = df_filtered.merge(crossreference[["permid","brs_id"]], how="left", on="permid")

# %%
df_filtered
# Out:
#                  issuer_name  company_inheriting parent_company str_001_s  \
# 0              BP France SAS                True         BP PLC        OK
# 1           BP Oil Espana SA                True         BP PLC        OK
# 2     Fresenius SE & Co KGaA               False              -        OK
# 3  Aria Energy Operating LLC                True         BP PLC        OK
#
#   str_002_ec str_003_ec str_004_asec   clarityid str_005_ec cs_001_sec  \
# 0   EXCLUDED         OK     EXCLUDED  4295866913         OK         OK
# 1   EXCLUDED         OK     EXCLUDED  4295889397         OK         OK
# 2         OK         OK           OK       15765         OK         OK
# 3   EXCLUDED         OK     EXCLUDED  5000645180         OK         OK
#
#   cs_003_sec cs_002_ec str_006_sec art_8_basicos      permid str_003b_ec  \
# 0         OK  EXCLUDED          OK            OK  4295866913          OK
# 1         OK  EXCLUDED          OK            OK  4295889397          OK
# 2         OK        OK          OK            OK  5001439044          OK
# 3         OK  EXCLUDED          OK            OK  5000645180          OK
#
#    brs_id
# 0     NaN
# 1  F31276
# 2  R65799
# 3     NaN

# %%
target_columns = [
    "issuer_name",
    "permid",
    "clarityid",
    "brs_id",
    "company_inheriting",
    "parent_company",
    "str_001_s",
    "str_002_ec",
    "str_003_ec",
    "str_003b_ec",
    "str_004_asec",
    "str_005_ec",
    "cs_001_sec",
    "cs_003_sec",
    "cs_002_ec",
    "str_006_sec",
    "art_8_basicos"
]

# sort columns following target_columns
df_filtered = df_filtered[target_columns]

# %%
final = df_filtered[~(df_filtered.brs_id.isna())].copy()

# %%
final
# Out:
#               issuer_name      permid   clarityid  brs_id  company_inheriting  \
# 1        BP Oil Espana SA  4295889397  4295889397  F31276                True
# 2  Fresenius SE & Co KGaA  5001439044       15765  R65799               False
#
#   parent_company str_001_s str_002_ec str_003_ec str_003b_ec str_004_asec  \
# 1         BP PLC        OK   EXCLUDED         OK          OK     EXCLUDED
# 2              -        OK         OK         OK          OK           OK
#
#   str_005_ec cs_001_sec cs_003_sec cs_002_ec str_006_sec art_8_basicos
# 1         OK         OK         OK  EXCLUDED          OK            OK
# 2         OK         OK         OK        OK          OK            OK

# %%
# define columns to process, i.e. strategies columns
columns_to_process = [    
     "str_001_s",
     "str_002_ec",
     "str_003_ec",
     "str_003b_ec",
     "str_004_asec",
     "str_005_ec",
     "cs_001_sec",
     "cs_003_sec",
     "cs_002_ec",
     "str_006_sec",
     "art_8_basicos"
 ]

def process_csv_files(
    df: pd.DataFrame,
    id_column: str = "brs_id",
    columns_to_process: list[str] = columns_to_process,
    output_dir: str =r"C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list",
):

    # keep from df id_columns + columns_to_process
    df = df[[id_column] + columns_to_process]

    # get date string yyyymmdd
    date = datetime.now()
    date_str = date.strftime("%y%m%d")

    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Set constant comment
    COMMENT = "manual override upload"

    # Process each column
    for column in columns_to_process:
        # Get unique values in the column
        unique_values = df[column].unique()

        # For each unique value, create a separate CSV file
        for value in unique_values:
            # Filter rows for current value
            filtered_df = df[df[column] == value]

            # Create output dataframe with required format
            output_df = pd.DataFrame(
                {
                    "ID Type": ["Issuer"] * len(filtered_df),
                    "ID": filtered_df["brs_id"],
                    "Start Date": [""] * len(filtered_df),
                    "Comment": [COMMENT] * len(filtered_df),
                }
            )

            # Create filename
            filename = f"{date_str}_{column}_{value}.csv"
            filepath = os.path.join(output_dir, filename)

            # Save to CSV
            output_df.to_csv(filepath, index=False)
            print(f"Created file: {filepath}")

# %%
df_inherit = df[df["issuer_name"].str.upper().str.contains("VOLKSWAGEN FINANCIAL SERVICES", na=False)]

# %%
df_inherit
# Out:
#                                              issuer_name  company_inheriting  \
# 5335                    Volkswagen Financial Services NV                True
# 8311                    Volkswagen Financial Services AG                True
# 18192  Volkswagen Financial Services Compania Financi...                True
#
#       parent_company str_001_s str_002_ec str_003_ec str_004_asec  clarityid  \
# 5335   Volkswagen AG        OK   EXCLUDED   EXCLUDED           OK     156287
# 8311   Volkswagen AG        OK   EXCLUDED   EXCLUDED           OK     246450
# 18192  Volkswagen AG        OK         OK         OK           OK  173000877
#
#       str_005_ec cs_001_sec cs_003_sec cs_002_ec str_006_sec art_8_basicos  \
# 5335    EXCLUDED   EXCLUDED   EXCLUDED  EXCLUDED    EXCLUDED            OK
# 8311    EXCLUDED   EXCLUDED   EXCLUDED  EXCLUDED    EXCLUDED            OK
# 18192         OK         OK         OK        OK          OK            OK
#
#            permid str_003b_ec
# 5335   4296552157          OK
# 8311   4296540381          OK
# 18192  5052540632          OK

# %%
# add brs_id to df_inherit
df_inherit = df_inherit.merge(crossreference[["permid","brs_id"]], how="left", on="permid")

# sort columns following target_columns
df_inherit = df_inherit[target_columns]

# %%
df_inherit = df_inherit[df_inherit.brs_id=="R62247"].copy()

# %%
df_inherit
# Out:
#                         issuer_name      permid clarityid  brs_id  \
# 1  Volkswagen Financial Services AG  4296540381    246450  R62247
#
#    company_inheriting parent_company str_001_s str_002_ec str_003_ec  \
# 1                True  Volkswagen AG        OK   EXCLUDED   EXCLUDED
#
#   str_003b_ec str_004_asec str_005_ec cs_001_sec cs_003_sec cs_002_ec  \
# 1          OK           OK   EXCLUDED   EXCLUDED   EXCLUDED  EXCLUDED
#
#   str_006_sec art_8_basicos
# 1    EXCLUDED            OK

# %%
# stack vertically final and df_inherit into new df
final = pd.concat([final, df_inherit])

# %%
final
# Out:
#                         issuer_name      permid   clarityid  brs_id  \
# 1                  BP Oil Espana SA  4295889397  4295889397  F31276
# 1  Volkswagen Financial Services AG  4296540381      246450  R62247
#
#    company_inheriting parent_company str_001_s str_002_ec str_003_ec  \
# 1                True         BP PLC        OK   EXCLUDED         OK
# 1                True  Volkswagen AG        OK   EXCLUDED   EXCLUDED
#
#   str_003b_ec str_004_asec str_005_ec cs_001_sec cs_003_sec cs_002_ec  \
# 1          OK     EXCLUDED         OK         OK         OK  EXCLUDED
# 1          OK           OK   EXCLUDED   EXCLUDED   EXCLUDED  EXCLUDED
#
#   str_006_sec art_8_basicos
# 1          OK            OK
# 1    EXCLUDED            OK

# %%
# change brs_id F31276 to Z10102
final.loc[final.brs_id=="F31276", "brs_id"] = "Z10102"

# %%
final.loc[final.brs_id=="R65799", "str_005_ec"] = "EXCLUDED"

# %%
final
# Out:
#               issuer_name      permid   clarityid  brs_id  company_inheriting  \
# 1        BP Oil Espana SA  4295889397  4295889397  F31276                True
# 2  Fresenius SE & Co KGaA  5001439044       15765  R65799               False
#
#   parent_company str_001_s str_002_ec str_003_ec str_003b_ec str_004_asec  \
# 1         BP PLC        OK   EXCLUDED         OK          OK     EXCLUDED
# 2              -        OK         OK         OK          OK           OK
#
#   str_005_ec cs_001_sec cs_003_sec cs_002_ec str_006_sec art_8_basicos
# 1         OK         OK         OK  EXCLUDED          OK            OK
# 2   EXCLUDED         OK         OK        OK          OK            OK

# %%
process_csv_files(final)
# Out:
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_001_s_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_002_ec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_003_ec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_003_ec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_003b_ec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_004_asec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_004_asec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_005_ec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_005_ec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_cs_001_sec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_cs_001_sec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_cs_003_sec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_cs_003_sec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_cs_002_ec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_006_sec_OK.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_str_006_sec_EXCLUDED.csv
# Created file: C:\Users\n740789\Documents\clarity_data_quality_controls\excel_books\brs_lists_to_upload\strategies_upload_list\250320_art_8_basicos_OK.csv
